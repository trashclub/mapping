# %%
import pandas as pd

# %%
df = pd.read_csv("raw/2010Census_Total_Population/data.csv")

# %%
df.reindex()
# Out:
#                          GEO_ID  \
# 0                            id
# 1      1000000US360470001001006
# 2      1000000US360470001001003
# 3      1000000US360470001001012
# 4      1000000US360470001001000
# ...                         ...
# 39144  1000000US360610170001002
# 39145  1000000US360610048004000
# 39146  1000000US360610160013002
# 39147  1000000US360610209011004
# 39148  1000000US360610221021001
#
#                                                     NAME P001001
# 0                                   Geographic Area Name   Total
# 1      Block 1006, Block Group 1, Census Tract 1, Kin...       4
# 2      Block 1003, Block Group 1, Census Tract 1, Kin...       0
# 3      Block 1012, Block Group 1, Census Tract 1, Kin...      75
# 4      Block 1000, Block Group 1, Census Tract 1, Kin...     181
# ...                                                  ...     ...
# 39144  Block 1002, Block Group 1, Census Tract 170, N...     515
# ...

# %%
df["GEOID10"] = df["GEO_ID"].apply(lambda x: x[9:])

# %%
df
# Out:
#                          GEO_ID  \
# 0                            id
# 1      1000000US360470001001006
# 2      1000000US360470001001003
# 3      1000000US360470001001012
# 4      1000000US360470001001000
# ...                         ...
# 39144  1000000US360610170001002
# 39145  1000000US360610048004000
# 39146  1000000US360610160013002
# 39147  1000000US360610209011004
# 39148  1000000US360610221021001
#
#                                                     NAME P001001  \
# 0                                   Geographic Area Name   Total
# 1      Block 1006, Block Group 1, Census Tract 1, Kin...       4
# 2      Block 1003, Block Group 1, Census Tract 1, Kin...       0
# 3      Block 1012, Block Group 1, Census Tract 1, Kin...      75
# 4      Block 1000, Block Group 1, Census Tract 1, Kin...     181
# ...                                                  ...     ...
# 39144  Block 1002, Block Group 1, Census Tract 170, N...     515
# ...

# %%
df.to_csv("final/popcounts_by_census_blocks.csv")
